# %% [markdown]
# # diccionarios, arreglo con una clave

# %%
vacio ={}

# %%
type(vacio)
# Out:
# dict

# %%
colores = {"amarillo":"yelow", "azul":"blue", "verde":"green"}

# %%
colores["verde"]
# Out:
# 'green'

# %%
#podemos borrar elmentos con de()
#podemos usar tambien .item para otras cosas
for c,v in colores.items():
    print(c,v)
# Out:
# amarillo yelow
# azul blue
# verde green
